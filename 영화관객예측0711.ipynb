# %% [markdown]
# <a href="https://colab.research.google.com/github/choeuneheol/python-practice/blob/master/%EC%98%81%ED%99%94%EA%B4%80%EA%B0%9D%EC%98%88%EC%B8%A10711.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\easy1\\OneDrive\\바탕 화면'

# %%
# %pwd
# Out:
# 'C:\\Users\\easy1\\OneDrive\\바탕 화면'

# %%
r'C:\Users\easy1\OneDrive\바탕 화면\개인스터디\영화관객수'
# Out:
# 'C:\\Users\\easy1\\OneDrive\\바탕 화면\\개인스터디\\영화관객수'

# %%
영화관예측0711 ='C:/Users/easy1/OneDrive/바탕 화면/개인스터디/영화관객수'
os.chdir
# Out:
# <function nt.chdir(path)>

# %%
# %pwd
# Out:
# 'C:\\Users\\easy1\\OneDrive\\바탕 화면'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\easy1\\OneDrive\\바탕 화면'

# %%
a_train = pd.read_csv('././개인스터디/영화관객수/movies_train.csv')
a_test = pd.read_csv('././개인스터디/영화관객수/movies_test.csv')
a_submission = pd.read_csv('././개인스터디/영화관객수/submission.csv')

# %%
a_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           243 non-null    object
#  1   distributor     243 non-null    object
#  2   genre           243 non-null    object
#  3   release_time    243 non-null    object
#  4   time            243 non-null    int64
#  5   screening_rat   243 non-null    object
#  6   director        243 non-null    object
#  7   dir_prev_bfnum  107 non-null    float64
#  8   dir_prev_num    243 non-null    int64
#  9   num_staff       243 non-null    int64
#  10  num_actor       243 non-null    int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.0+ KB

# %%
a_test.head()
# Out:
#          title distributor   genre release_time  time screening_rat director  \
# 0       용서는 없다      시네마서비스     느와르   2010-01-07   125      청소년 관람불가      김형준
# 1  아빠가 여자를 좋아해      (주)쇼박스  멜로/로맨스   2010-01-14   113       12세 관람가      이광재
# 2          하모니   CJ 엔터테인먼트     드라마   2010-01-28   115       12세 관람가      강대규
# 3          의형제      (주)쇼박스      액션   2010-02-04   116       15세 관람가       장훈
# 4        평행 이론   CJ 엔터테인먼트      공포   2010-02-18   110       15세 관람가      권호영
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor
# 0    3.005290e+05             2        304          3
# 1    3.427002e+05             4        275          3
# 2    4.206611e+06             3        419          7
# 3    6.913420e+05             2        408          2
# 4    3.173800e+04             1        380          1

# %%
a_train.head()
# Out:
#        title   distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3   나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4       불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0             NaN             0         91          2        23398
# 1      1161602.50             2        387          3      7072501
# 2       220775.25             4        343          4      6959083
# 3        23894.00             2         20          6       217866
# 4            1.00             1        251          2       483387

# %%
a_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  270 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 56.4+ KB

# %%
grid_ndf = sns.pairplot(a_train)
plt.show()
plt.close()

# %%
grid_ndf = sns.pairplot(a_test)
plt.show()
plt.close()

# %%
import missingno as msno

# %%
msno.matrix(a_train)
plt.show()

# %%
msno.matrix(a_test)
plt.show()

# %%
sns.countplot(x='director', data=a_train);
# Out:
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50725 (\N{HANGUL SYLLABLE OG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
figure, axes = plt.subplots(nrows=2, ncols=1)
plt.tight_layout()

# %%
sns.barplot(x='director', y='dir_prev_bfnum', data=a_train)
sns.barplot(x='director', y='dir_prev_bfnum', data=a_test)
# Out:
# <AxesSubplot:xlabel='director', ylabel='dir_prev_bfnum'>
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44608 (\N{HANGUL SYLLABLE GIM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
mpl.rc('font', size=6)
mpl.rc('axes', titlesize=1)
figure, axes = plt.subplots(nrows=2, ncols=1)
plt.tight_layout()
figure.set_size_inches(18, 17)

sns.barplot(x='director', y='dir_prev_bfnum', data=a_train, ax=axes[0])
# Out:
# <AxesSubplot:xlabel='director', ylabel='dir_prev_bfnum'>
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50725 (\N{HANGUL SYLLABLE OG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\easy1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#시각화만해본결과 전작품평균관객수의 결측치가 상당히 많아서 제거를 해야겠다.
