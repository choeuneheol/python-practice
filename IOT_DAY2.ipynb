# %% [markdown]
# <a href="https://colab.research.google.com/github/choeuneheol/python-practice/blob/master/IOT_DAY2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#리눅스기초


#리눅스의 장점
- 높은 품질의 다양한 소프트웨어를 리눅스에서 돌릴 수 있음(아파치 http, 

서버나 MYSQL 데이터베이스 등)

- 스크립트를 통해 많은 부분을 자동화 할 수 있어 운영에 편리함

- 브라우저에서 요청을 받아들이는 웹 서버, 비즈니스 로직을 수행하는

애플리케이션 서버, 데이터를 저장하는 데이터베이스의 운영 체제로 

리눅스를 사용ㅇ하는 것이 일반적이기 때문임

- 개발 환경 구축이 용이하며 비용이 발생하지 않름

- 오픈 소스여서 운영 체제의 내부 동작을 확인할 수 있음

#리눅스의 단점

- 리눅스는 윈도우나 맥보다 사용 애플리케이션이 많지 않음

- 마이크로소프트의 워드나 엑셀 파일을 편집하려면 리브레오피스

(LibreOffice)

# 리눅스의 개요

리눅스 = 무료 유닉스

1991년 리누스 토르발스가 버전 0.01을 최초로 작성

1992년 0.02 버젼을 공개하면서 시작됨

리눅스 토르발스는 커널만 개발함

배포판을 구성

#GNU 프로젝트

1984년에 리차드 스톨만에 의해서 프로젝트가 시작

목표는 모두가 공유할 수 있는 소프트웨어를 만드는 것

리차드 스톨만은 1985년에 자유 소프트웨어 제단을 설립

목표는 GNU프로젝트에서 제작한 소프트웨어를 지원함으로써 컴퓨터

프로그램의 복제, 변경, 소스 코드의 사용에 대한 제한을 철폐 하는것

GPL을 따름. 이 라이선스는 자유 소프트웨어의 수정과 공유의 자유를 보장함

프리웨어라는 개념을 뛰어넘어서 진정한 자유에 대한 개념

자유 소프트웨어는 심지어 무료로 얻은 소프트웨어를 유상으로 판매할 자유도 보장

#커널

http://www.Kernel.org 에서 최신버젼을 무료로 다운로드

커널 버젼의 의미 (예: 3.17.4)

3은 주버젼

17은 부 부젼

4는 패치 버젼

#라즈비안 파이 OS

라즈베리 파이 재단이 개발한 라즈베리 파이 전용 운영 체제

과거에는 라즈비안이라는 이름을 사용

라즈베리 파이 OS는 마이크 톰

#시작과 종료

종료하는 방법

종료와 재부팅은 sudo필요 Ssudo su-

'shutdown -p now', 'halt -p', 'init 0'

시스템 재부팅

'shutdown -r now','reboot', 'init 6'

로그아웃

'logout' 

'exit'는 까만창 닫는데 쓰임

#런레벨 

init 명령어 뒤에 붙는 수자를 런레벨이라고 부르다

런레벨 모드를 확인하려면, /lib/ststemd/system/디렉터리의 

runlevel#.target 파일을 확인

셀과 명령어

리눅스에 로그인했다면 곧바로 명령어를 봐야한다

다음과 같은 S기호 뒤에 date 명령어를 입력하고 엔터 누르시오

pwd

cd / etc <- etc 디렉토리로 이동

/etc $ cd ~

~ $ pwd

cd ~ <- 다시 홈 디렉토리로 이동

echo Hello <- echo 명령어뒤에는 출력됨

#셸과 명령어

이외에도 명령어가 다양함

처음 설치할 떄부터 수십 개 이상의 명령어가 포함되어 있음

이 모든 명령어를 외울 필요는 없음

필수적인 명렁어들을 익힌 뒤에 필요할 때마다 하나씩 익히면 됨

필요한 작업에 딱 맞는 명령어가 없다면 기존 명령어들을 조합하여 사용하면됨

리눅스는 단순한 명령어들을 조합하여 복잡한 작업을 처리할 수 있도록 설계

에러에 대해서

리눅스 환경에서 실습하다 보면 오타 등으로 인해 다양한 에러를 만나게 된다

에러를 만나면 당황하지 말고 침착하게 표시된 에러 메세지를 읽으면서 원인을 파악해 보기바람

에러 메세지에는 에러가 발생한 원인에 대해 실마리가 담겨 있다

$ < 프롬프트

에디터 사용

gedit의 기본적인 사용법을 익힌다
vi의 사용법을 사용한다

입력모드 i또는 a

ex모드 :(콜론)

명령모드로 돌아오는 방법 esc

vi 기능요약

i 현재 커서의 위치에서 입력

a 현재 커서의 위치 다음 칸부터 입력

L 현재 컴서 줄의 맨 앞에서부터 입력 쉬프트+l

A 현재 커서 줄의 맨 마지막부터 입력 쉬트트+A
